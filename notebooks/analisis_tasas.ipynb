# %%
import pandas as pd
df["Tasa de política monetaria"].describe()
# Out:
# count    10342.000000
# mean         7.816066
# std          5.564469
# min          1.750000
# 25%          4.250000
# 50%          6.500000
# 75%          9.500000
# max         32.000000
# Name: Tasa de política monetaria, dtype: float64

# %%
import pandas as pd
df[df["Tasa de política monetaria"] == df["Tasa de política monetaria"].min()]
# Out:
#      Periodo(MMM DD, AAAA)  Tasa de política monetaria
# 8263            2020-09-28                        1.75
# 8264            2020-09-29                        1.75
# 8265            2020-09-30                        1.75
# 8266            2020-10-01                        1.75
# 8267            2020-10-02                        1.75
# ...                    ...                         ...
# 8626            2021-09-26                        1.75
# 8627            2021-09-27                        1.75
# 8628            2021-09-28                        1.75
# 8629            2021-09-29                        1.75
# 8630            2021-09-30                        1.75
#
# [368 rows x 2 columns]

# %%
import pandas as pd
df[df["Tasa de política monetaria"] == df["Tasa de política monetaria"].max()]
# Out:
#     Periodo(MMM DD, AAAA)  Tasa de política monetaria
# 104            1998-05-28                        32.0
# 105            1998-05-29                        32.0
# 106            1998-05-30                        32.0
# 107            1998-05-31                        32.0
# 108            1998-06-01                        32.0
# ..                    ...                         ...
# 264            1998-11-04                        32.0
# 265            1998-11-05                        32.0
# 266            1998-11-06                        32.0
# 267            1998-11-07                        32.0
# 268            1998-11-08                        32.0
#
# [165 rows x 2 columns]

# %% [markdown]
# # Conclusiones
#
# Tras analizar 10.342 observaciones de la tasa de política monetaria de Colombia entre 1998 y 2026, se obtuvieron los siguientes resultados:
#
# - Tasa mínima observada: **1,75%**, registrada el **28 de septiembre de 2020**.
# - Tasa máxima observada: **32,00%**, registrada el **28 de mayo de 1998**.
# - Tasa promedio durante el período analizado: **7,8%**.

# %%
df["Periodo(MMM DD, AAAA)"] = pd.to_datetime(
    df["Periodo(MMM DD, AAAA)"]
)
import matplotlib.pyplot as plt

plt.figure(figsize=(12,6))
plt.grid(True)
plt.plot(
    df["Periodo(MMM DD, AAAA)"],
    df["Tasa de política monetaria"]
)

plt.title("Tasa de Política Monetaria en Colombia")
plt.xlabel("Fecha")
plt.ylabel("Tasa (%)")

plt.show()

# %% [markdown]
# # Observaciones
# Se observan las fluctuaciones generadas por el cambio en la tasa de interés de PM, destacando la crisis de finales de los 90´s, con tasas que alcanzaron un máximo de **32%**, como también el bajo nivel de las tasas post-pandemia, alcanzando niveles mínimos del **1.75%**
